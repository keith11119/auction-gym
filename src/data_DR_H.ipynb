# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from main import parse_config, instantiate_agents, instantiate_auction
from tqdm.notebook import tqdm

# %%
# Parse configuration file
rng, config, agent_configs, agents2items, agents2item_values,\
num_runs, max_slots, embedding_size, embedding_var,\
obs_embedding_size = parse_config('../config/FP_DR_TS_H.json')

# %%
# Instantiate Agent and Auction objects
agents = instantiate_agents(rng, agent_configs, agents2item_values, agents2items)
# bid = value * estimated_CTR * gamma
# Instantiate Auction object
auction, num_iter, rounds_per_iter, output_dir =\
    instantiate_auction(rng,
                        config,
                        agents2items,
                        agents2item_values,
                        agents,
                        max_slots,
                        embedding_size,
                        embedding_var,
                        obs_embedding_size)

# %%
# Placeholders for output
auction_revenue = []
social_welfare = []
social_surplus = []
# Run repeated auctions
# This logic is encoded in the `simulation_run()` method in main.py
for i in tqdm(range(num_iter)):
    print( f'number of iteration: {i}\n')
    # Simulate impression opportunities
    for _ in range(rounds_per_iter):
        auction.simulate_opportunity()

    # Log 'Gross utility' or welfare
    social_welfare.append(sum([agent.gross_utility for agent in auction.agents]))

    # Log 'Net utility' or surplus
    social_surplus.append(sum([agent.net_utility for agent in auction.agents]))

    # Update agents (does nothing in this example, as we have truthful oracles)
    # Clear running metrics
    for agent_id, agent in enumerate(auction.agents):
        print(f'agent: {agent_id}\n' )
        agent.update(iteration=i)
        agent.clear_utility()
        agent.clear_logs()

    # Log revenue
    auction_revenue.append(auction.revenue)
    auction.clear_revenue()

# Rescale metrics per auction round
auction_revenue = np.array(auction_revenue) / rounds_per_iter
social_welfare = np.array(social_welfare) / rounds_per_iter
social_surplus = np.array(social_surplus) / rounds_per_iter
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# number of iteration: 0
#
# agent: 0
# DR 1:   0%|          | 0/16384 [00:00<?, ?it/s]
# DR 1:   3%|▎         | 484/16384 [00:00<00:03, 4834.98it/s]
# DR 1:   6%|▋         | 1045/16384 [00:00<00:02, 5286.32it/s]
# DR 1:  10%|▉         | 1607/16384 [00:00<00:02, 5434.79it/s]
# DR 1:  13%|█▎        | 2169/16384 [00:00<00:02, 5504.43it/s]
# DR 1:  17%|█▋        | 2720/16384 [00:00<00:02, 5483.70it/s]
# DR 1:  20%|██        | 3295/16384 [00:00<00:02, 5571.70it/s]
# DR 1:  24%|██▎       | 3869/16384 [00:00<00:02, 5625.24it/s]
# DR 1:  27%|██▋       | 4446/16384 [00:00<00:02, 5668.19it/s]
# DR 1:  31%|███       | 5013/16384 [00:00<00:02, 5664.93it/s]
# DR 1:  34%|███▍      | 5581/16384 [00:01<00:01, 5666.77it/s]
# DR 1:  38%|███▊      | 6148/16384 [00:01<00:01, 5653.21it/s]
# DR 1:  41%|████      | 6719/16384 [00:01<00:01, 5667.69it/s]
# DR 1:  45%|████▍     | 7295/16384 [00:01<00:01, 5692.87it/s]
# DR 1:  50%|████▉     | 8170/16384 [00:01<00:01, 5597.78it/s]
# /Users/keithwu/Documents/GitHub/auction-gym/src/Models.py:44: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3281.)
#   P = (1 + torch.exp(1 - X.matmul(self.m[item, :].T))) ** (-1)
# Stopping at Epoch 8170
# DR 1:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR
# Initialising Policy:  18%|█▊        | 3027/16384 [00:01<00:07, 1761.70it/s]
# Initialising Policy:  20%|█▉        | 3204/16384 [00:01<00:07, 1752.76it/s]
# Initialising Policy:  21%|██        | 3380/16384 [00:01<00:07, 1744.01it/s]
# Initialising Policy:  22%|██▏       | 3558/16384 [00:02<00:07, 1753.48it/s]
# Initialising Policy:  23%|██▎       | 3739/16384 [00:02<00:07, 1768.87it/s]
# Initialising Policy:  24%|██▍       | 3917/16384 [00:02<00:07, 1768.63it/s]
# Initialising Policy:  25%|██▍       | 4094/16384 [00:02<00:07, 1736.80it/s]
# Initialising Policy:  26%|██▌       | 4268/16384 [00:02<00:06, 1736.78it/s]
# Initialising Policy:  27%|██▋       | 4443/16384 [00:02<00:06, 1738.93it/s]
# Initialising Policy:  28%|██▊       | 4617/16384 [00:02<00:06, 1733.49it/s]
# Initialising Policy:  29%|██▉       | 4791/16384 [00:02<00:06, 1733.78it/s]
# Initialising Policy:  30%|███       | 4969/16384 [00:02<00:06, 1746.77it/s]
# Initialising Policy:  31%|███▏      | 5149/16384 [00:02<00:06, 1762.45it/s]
# Initialising Policy:  33%|███▎      | 5326/16384 [00:03<00:06, 1756.44it/s]
# Initialising Policy:  34%|███▎      | 5502/16384 [00:03<00:06, 1748.38it/s]
# Initialising Policy:  35%|███▍      | 5677/16384 [00:03<00:06, 1748.40it/s]
# Initialising Policy:  36%|███▌      | 5855/16384 [00:03<00:05, 1756.09it/s]
# Initialising Policy:  37%|███▋      | 6036/16384 [00:03<00:05, 1770.38it/s]
# Initialising Policy:  38%|███▊      | 6215/16384 [00:03<00:05, 1773.27it/s]
# Initialising Policy:  39%|███▉      | 6393/16384 [00:03<00:05, 1773.99it/s]
# Initialising Policy:  40%|████      | 6573/16384 [00:03<00:05, 1780.76it/s]
# Initialising Policy:  41%|████      | 6752/16384 [00:03<00:05, 1778.56it/s]
# Initialising Policy:  42%|████▏     | 6933/16384 [00:03<00:05, 1787.48it/s]
# Initialising Policy:  43%|████▎     | 7115/16384 [00:04<00:05, 1794.70it/s]
# Initialising Policy:  45%|████▍     | 7295/16384 [00:04<00:05, 1787.52it/s]
# Initialising Policy:  46%|████▌     | 7474/16384 [00:04<00:04, 1785.59it/s]
# Initialising Policy:  47%|████▋     | 7749/16384 [00:04<00:04, 1766.38it/s]
# Stopping at Epoch 7749
# Predicted mu Gammas:  tensor(0.9563, grad_fn=<MinBackward1>) tensor(1.0109, grad_fn=<MaxBackward1>) tensor(0.9997, grad_fn=<MeanBackward0>)
# Predicted sigma Gammas:  tensor(0.0398, grad_fn=<MinBackward1>) tensor(0.1154, grad_fn=<MaxBackward1>) tensor(0.0505, grad_fn=<MeanBackward0>)
# DR 1:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR
# Initialising Policy:  69%|██████▉   | 11335/16384 [00:06<00:03, 1602.60it/s]
# Initialising Policy:  70%|███████   | 11496/16384 [00:07<00:03, 1599.66it/s]
# Initialising Policy:  71%|███████   | 11659/16384 [00:07<00:02, 1607.12it/s]
# Initialising Policy:  72%|███████▏  | 11823/16384 [00:07<00:02, 1614.25it/s]
# Initialising Policy:  73%|███████▎  | 11985/16384 [00:07<00:02, 1612.34it/s]
# Initialising Policy:  74%|███████▍  | 12151/16384 [00:07<00:02, 1625.69it/s]
# Initialising Policy:  75%|███████▌  | 12319/16384 [00:07<00:02, 1640.35it/s]
# Initialising Policy:  76%|███████▌  | 12487/16384 [00:07<00:02, 1649.23it/s]
# Initialising Policy:  77%|███████▋  | 12652/16384 [00:07<00:02, 1630.66it/s]
# Initialising Policy:  78%|███████▊  | 12817/16384 [00:07<00:02, 1634.54it/s]
# Initialising Policy:  79%|███████▉  | 12981/16384 [00:07<00:02, 1625.35it/s]
# Initialising Policy:  80%|████████  | 13144/16384 [00:08<00:02, 1619.08it/s]
# Initialising Policy:  81%|████████  | 13306/16384 [00:08<00:01, 1614.63it/s]
# Initialising Policy:  82%|████████▏ | 13468/16384 [00:08<00:01, 1615.92it/s]
# Initialising Policy:  83%|████████▎ | 13634/16384 [00:08<00:01, 1627.17it/s]
# Initialising Policy:  84%|████████▍ | 13800/16384 [00:08<00:01, 1634.39it/s]
# Initialising Policy:  85%|████████▌ | 13966/16384 [00:08<00:01, 1640.58it/s]
# Initialising Policy:  86%|████████▋ | 14132/16384 [00:08<00:01, 1644.72it/s]
# Initialising Policy:  87%|████████▋ | 14297/16384 [00:08<00:01, 1643.68it/s]
# Initialising Policy:  88%|████████▊ | 14464/16384 [00:08<00:01, 1650.98it/s]
# Initialising Policy:  89%|████████▉ | 14632/16384 [00:08<00:01, 1659.47it/s]
# Initialising Policy:  90%|█████████ | 14801/16384 [00:09<00:00, 1666.50it/s]
# Initialising Policy:  91%|█████████▏| 14972/16384 [00:09<00:00, 1677.27it/s]
# Initialising Policy:  92%|█████████▏| 15140/16384 [00:09<00:00, 1677.67it/s]
# Initialising Policy:  93%|█████████▎| 15308/16384 [00:09<00:00, 1676.87it/s]
# Initialising Policy:  94%|█████████▍| 15476/16384 [00:09<00:00, 1672.64it/s]
# Initialising Policy:  95%|█████████▌| 15644/16384 [00:09<00:00, 1658.24it/s]
# Initialising Policy:  96%|█████████▋| 15810/16384 [00:09<00:00, 1656.05it/s]
# Initialising Policy:  98%|█████████▊| 15976/16384 [00:09<00:00, 1649.77it/s]
# Initialising Policy:  99%|█████████▊| 16141/16384 [00:09<00:00, 1639.60it/s]
# Initialising Policy: 100%|██████████| 16384/16384 [00:10<00:00, 1629.87it/s]
# Predicted mu Gammas:  tensor(0.9085, grad_fn=<MinBackward1>) tensor(1.0788, grad_fn=<MaxBackward1>) tensor(0.9977, grad_fn=<MeanBackward0>)
# Predicted sigma Gammas:  tensor(0.0271, grad_fn=<MinBackward1>) tensor(0.1026, grad_fn=<MaxBackward1>) tensor(0.0509, grad_fn=<MeanBackward0>)
# DR 3:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR
# DR 11:  11%|█         | 3561/32768 [00:03<00:27, 1062.34it/s]
# DR 11:  11%|█         | 3669/32768 [00:03<00:27, 1065.91it/s]
# DR 11:  12%|█▏        | 3776/32768 [00:03<00:27, 1051.25it/s]
# DR 11:  12%|█▏        | 3883/32768 [00:03<00:27, 1055.56it/s]
# DR 11:  12%|█▏        | 3991/32768 [00:03<00:27, 1061.35it/s]
# DR 11:  13%|█▎        | 4099/32768 [00:03<00:26, 1065.79it/s]
# DR 11:  13%|█▎        | 4276/32768 [00:04<00:26, 1063.02it/s]
# Stopping at Epoch 4276
# DR 11 Number of samples:  torch.Size([3483, 2])
# DR 11 Predicted Gammas:  0.5146758 0.7458426 0.65882313
# agent: 11
# DR 12:   0%|          | 0/16384 [00:00<?, ?it/s]
# DR 12:   6%|▋         | 1025/16384 [00:00<00:03, 5112.19it/s][A
# Stopping at Epoch 1025
# AUC predicting P(win):				 0.7738223461593572
# Estimated Utility	 Mean Error:			 0.0028574256260997946
# Estimated Utility	 Mean Absolute Error:	 0.16412223756439787
# DR 12:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR 12:   2%|▏         | 565/32768 [00:00<00:05, 5640.42it/s]
# DR 12:   3%|▎         | 1130/32768 [00:00<00:05, 5590.32it/s]
# DR 12:   5%|▌         | 1690/32768 [00:00<00:05, 5481.63it/s]
# DR 12:   7%|▋         | 2251/32768 [00:00<00:05, 5528.24it/s]
# Epoch 01165: reducing learning rate of group 0 to 6.0000e-04.
# Epoch 01422: reducing learning rate of group 0 to 1.2000e-04.
# Epoch 01679: reducing learning rate of group 0 to 2.4000e-05.
# Epoch 01936: reducing learning rate of group 0 to 4.8000e-06.
# Epoch 02193: reducing learning rate of group 0 to 9.6000e-07.
# DR 12:   7%|▋         | 2306/32768 [00:00<00:05, 5508.22it/s]
# Stopping at Epoch 2306
# AUC predicting P(win):				 0.7682409866963527
# Estimated Utility	 Mean Error:			 0.006800065636372704
# Estimated Utility	 Mean Absolute Error:	 0.16625528861463165
# DR 12:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR 12:   0%|          | 101/32768 [00:00<00:32, 1009.19it/s]
# DR 12:   1%|          | 208/32768 [00:00<00:31, 1039.20it/s]
# DR 12:   1%|          | 319/32768 [00:00<00:30, 1069.47it/s]
# DR 12:   1%|▏         | 426/32768 [00:00<00:30, 1068.08it/s]
# DR 12:   2%|▏         | 539/32768 [00:00<00:29, 1088.91it/s]
# DR 12:   2%|▏         | 648/32768 [00:00<00:29, 1084.02it/s]
# DR 12:   2%|▏         | 757/32768 [00:00<00:29, 1074.13it/s]
# DR 12:   3%|▎         | 865/32768 [00:00<00:29, 1067.35it/s]
# DR 12:   3%|▎         | 972/32768 [00:00<00:30, 1054.56it/s]
# DR 12:   3%|▎         | 1086/32768 [00:01<00:29, 1079.36it/s]
# DR 12:   4%|▎         | 1201/32768 [00:01<00:28, 1099.67it/s]
# DR 12:   4%|▍         | 1315/32768 [00:01<00:28, 1109.78it/s]
# DR 12:   4%|▍         | 1427/32768 [00:01<00:28, 1099.38it/s]
# DR 12:   5%|▍         | 1537/32768 [00:01<00:29, 1073.64it/s]
# DR 12:   5%|▌         | 1648/32768 [00:01<00:28, 1083.76it/s]
   0%|          | 0/16384 [00:00<?, ?it/s]
# DR 13:   3%|▎         | 448/16384 [00:00<00:03, 4474.54it/s]
# DR 13:   6%|▋         | 1025/16384 [00:00<00:03, 4493.13it/s][A
# Stopping at Epoch 1025
# AUC predicting P(win):				 0.8760068106610204
# Estimated Utility	 Mean Error:			 -0.0014000408465275971
# Estimated Utility	 Mean Absolute Error:	 0.3247479759793573
# DR 13:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR 13:   2%|▏         | 555/32768 [00:00<00:05, 5542.25it/s]
# DR 13:   3%|▎         | 1110/32768 [00:00<00:05, 5546.12it/s]
# DR 13:   5%|▌         | 1678/32768 [00:00<00:05, 5605.70it/s]
# DR 13:   7%|▋         | 2239/32768 [00:00<00:05, 5592.89it/s]
# DR 13:   9%|▊         | 2800/32768 [00:00<00:05, 5597.27it/s]
# Epoch 02051: reducing learning rate of group 0 to 6.0000e-04.
# Epoch 02308: reducing learning rate of group 0 to 1.2000e-04.
# Epoch 02565: reducing learning rate of group 0 to 2.4000e-05.
# Epoch 02822: reducing learning rate of group 0 to 4.8000e-06.
# Epoch 03079: reducing learning rate of group 0 to 9.6000e-07.
# DR 13:  10%|█         | 3326/32768 [00:00<00:05, 5586.98it/s]
# Stopping at Epoch 3326
# AUC predicting P(win):				 0.8848905723905724
# Estimated Utility	 Mean Error:			 0.008796146216611664
# Estimated Utility	 Mean Absolute Error:	 0.32566040147622344
# DR 13:   0%|          | 0/32768 [00:00<?, ?it/s]
# DR 13:   0%|          | 104/32768 [00:00<00:31, 1038.74it/s]
# DR 13:   1%|          | 217/32768 [00:00<00:29, 1089.49it/s]
# DR 13:   1%|          | 329/32768 [00:00<00:29, 1099.01it/s]
# DR 13:   1%|▏         | 441/32768 [00:00<00:29, 1107.22it/s]
# DR 13:   2%|▏         | 552/32768 [00:00<00:29, 1101.35it/s]
# DR 13:   2%|▏         | 663/32768 [00:00<00:29, 1089.55it/s]
# DR 13:   2%|▏         | 772/32768 [00:00<00:29, 1089.38it/s]
# DR 13:   3%|▎         | 881/32768 [00:00<00:29, 1085.34it/s]
# DR 13:   3%|▎         | 992/32768 [00:00<00:29, 1090.40it/s]
# DR 13:   3%|▎         | 1102/32768 [00:01<00:29, 1066.50it/s]
# DR 13:   4%|▎         | 1209/32768 [00:01<00:30, 1033.63it/s]
# DR 13:   4%|▍         | 1316/32768 [00:01<00:30, 1042.91it/s]
# DR 13:   4%|▍         | 1423/32768 [00:01<00:29, 1050.18it/s]
# DR 13:   5%|▍         | 1534/32768 [00:01<00:29, 1065.49it/s]
# DR 13:   5%|▌         | 1643/32768 [00:01<00:29, 1069.77it/s]
# DR 13:   5%|▌         | 1755/32768 [00:01<00:28, 1084.09it/s]
# DR 13:   6%|▌         | 1868/32768 [00:01<00:28, 1095.59it/s]
# DR 13:   6%|▌         | 1978/32768 [00:01<00:28, 1085.23it/s]
# DR 13:   6%|▋         | 2087/32768 [00:01<00:28, 1079.63it/s]
# DR 13:   7%|▋         | 2196/32768 [00:02<00:28, 1062.66it/s]
# DR 13:   7%|▋         | 2303/32768 [00:02<00:28, 1062.57it/s]
# DR 13:   7%|▋         | 2410/32768 [00:02<00:28, 1062.55it/s]
# DR 13:   8%|▊         | 2519/32768 [00:02<00:28, 1067.98it/s]
# DR 13:   8%|▊         | 2628/32768 [00:02<00:28, 1074.36it/s]
# DR 13:   8%|▊         | 2736/32768 [00:02<00:28, 1057.52it/s]
# DR 13:   9%|▊         | 2845/32768 [00:02<00:28, 1066.20it/s]
# DR 13:   9%|▉         | 2954/32768 [00:02<00:27, 1072.21it/s]
# DR 13:   9%|▉         | 3062/32768 [00:02<00:27, 1061.38it/s]
# DR 13:  10%|▉         | 3169/32768 [00:02<00:28, 1033.27it/s]
# DR 13:  10%|▉         | 3273/32768 [00:03<00:29, 999.47it/s]
# DR 13:  10%|█         | 3375/32768 [00:03<00:29, 1002.89it/s]
# DR 13:  11%|█         | 3477/32768 [00:03<00:29, 1005.24it/s]
# DR 13:  11%|█         | 3581/32768 [00:03<00:28, 1014.57it/s]
# DR 13:  11%|█         | 3686/32768 [00:03<00:28, 1024.39it/s]
# DR 13:  12%|█▏        | 3789/32768 [00:03<00:28, 1007.10it/s]
# DR 13:  12%|█▏        | 3893/32768 [00:03<00:28, 1016.14it/s]
# DR 13:  13%|█▎        | 4106/32768 [00:03<00:27, 1055.88it/s]
# Stopping at Epoch 4106
# DR 13 Number of samples:  torch.Size([3330, 2])
# DR 13 Predicted Gammas:  0.48598936 1.0 0.9025692
# agent: 13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 23
#      21 for agent_id, agent in enumerate(auction.agents):
#      22     print(f'agent: {agent_id}\n' )
# ---> 23     agent.update(iteration=i)
#      24     agent.clear_utility()
#      25     agent.clear_logs()
#
# File ~/Documents/GitHub/auction-gym/src/Agent.py:94, in Agent.update(self, iteration, plot, figsize, fontsize)
#      91 self.allocator.update(contexts[won_mask], items[won_mask], outcomes[won_mask], iteration, plot, figsize, fontsize, self.name)
#      93 # Update bidding model with all data
# ---> 94 self.bidder.update(contexts, values, bids, prices, outcomes, estimated_CTRs, won_mask, iteration, plot, figsize, fontsize, self.name)
#
# File ~/Documents/GitHub/auction-gym/src/Bidder.py:495, in DoublyRobustBidder.update(self, contexts, values, bids, prices, outcomes, estimated_CTRs, won_mask, iteration, plot, figsize, fontsize, name)
#     493 orig_features = torch.Tensor(np.hstack((estimated_CTRs.reshape(-1,1), values.reshape(-1,1), gammas_numpy.reshape(-1, 1))))
#     494 W = self.winrate_model(orig_features).squeeze().detach().numpy()
# --> 495 print('AUC predicting P(win):\t\t\t\t', roc_auc_score(won_mask.astype(np.uint8), W))
#     497 V = estimated_CTRs * values
#     498 P = estimated_CTRs * values * gammas_numpy
#
# File ~/opt/anaconda3/envs/auction-gym/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:567, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     565     labels = np.unique(y_true)
#     566     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 567     return _average_binary_score(
#     568         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     569         y_true,
#     570         y_score,
#     571         average,
#     572         sample_weight=sample_weight,
#     573     )
#     574 else:  # multilabel-indicator
#     575     return _average_binary_score(
#     576         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     577         y_true,
#    (...)
#     580         sample_weight=sample_weight,
#     581     )
#
# File ~/opt/anaconda3/envs/auction-gym/lib/python3.10/site-packages/sklearn/metrics/_base.py:75, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
# ---> 75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77 check_consistent_length(y_true, y_score, sample_weight)
#      78 y_true = check_array(y_true)
#
# File ~/opt/anaconda3/envs/auction-gym/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:337, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     335 """Binary roc auc score."""
#     336 if len(np.unique(y_true)) != 2:
# --> 337     raise ValueError(
#     338         "Only one class present in y_true. ROC AUC score "
#     339         "is not defined in that case."
#     340     )
#     342 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     343 if max_fpr is None or max_fpr == 1:
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# data generation
# just take the first agent's data (dont know is it correct)
# Q2 the bidder updates seems does not use the utilities but the estimated_CTRs instead
# it seems to only use the utilities to calculate the welfare and surplu
# Input: context
# Action: bid/ gamma
# Output: reward
trained_welfare = {}
trained_surplus = {}
trained_data = {}
val_data = {}
test_data = {}
num_data = [7000, 2000, 1000]

for i, data in enumerate([trained_data, val_data, test_data]):
    for _ in range(num_data[i]):
        auction.simulate_opportunity()
    for agent_id, age nt in enumerate(auction.agents):
        contexts = np.array(list(opp.context for opp in agent.logs))
        bids = np.array(list(opp.bid for opp in agent.logs))
        prices = np.array(list(opp.price for opp in agent.logs))
        values = np.array(list(opp.value for opp in agent.logs))
        outcomes = np.array(list(opp.outcome for opp in agent.logs))
        won_mask = np.array(list(opp.won for opp in agent.logs))
        estimated_CTRs = np.array(list(opp.estimated_CTR for opp in agent.logs))
        gammas = np.array(list(opp.detach().numpy() for opp in agent.bidder.gammas))
        utilities = np.zeros_like(values)
        utilities[won_mask] = (values[won_mask] * outcomes[won_mask]) - prices[won_mask]
        data[agent_id] = np.hstack((contexts, estimated_CTRs.reshape(-1, 1),values.reshape(-1, 1), bids.reshape(-1, 1), gammas.reshape(-1,1), utilities.reshape(-1, 1)))
        agent.clear_utility()
        agent.clear_logs()
        # may consider including estimated_CTRs as input features as well
    auction.clear_revenue()

# %%
data[12]
# Out:
# array([[ 0.50659343, -0.17838922, -1.8990778 , ...,  0.41460285,
#          1.        ,  0.        ],
#        [ 0.25900903,  1.49187791,  0.81739224, ...,  0.648367  ,
#          0.77205825,  1.31546977],
#        [ 0.25192821, -0.15214545, -1.8821809 , ...,  0.66037563,
#          0.96316123,  0.        ],
#        ...,
#        [-0.48153778, -1.70403851,  0.16178272, ...,  0.43138994,
#          1.        ,  0.        ],
#        [-0.48613434, -1.74773344,  2.42588187, ...,  0.82454509,
#          0.6303516 ,  1.13929168],
#        [-0.78888038, -1.06598997, -1.25491345, ...,  0.31214703,
#          1.        ,  0.        ]])

# %%
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def gridSearch(model, param_grid, input_data, output_data):
    grid_cv = GridSearchCV(model, param_grid, cv=5, n_jobs=-1).fit(input_data, output_data)
    print("Param for GS", grid_cv.best_params_)
    print("CV score for GS", grid_cv.best_score_)
    return grid_cv.best_estimator_

# %%
param_grid = {
    'max_depth': [3, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10, 15]
}
model = tree.DecisionTreeRegressor()
# should I set random state here?
# mb k-fold is not nesscary here
# input_data = np.hstack((trained_data[0][:, :5], trained_data[0][:, 5].reshape(-1, 1)))

# %%
# context with bid
for agent_id in trained_data.keys():
    input_train_data = trained_data[agent_id][:, :5]
    label_train_data = trained_data[agent_id][:, 7]
    print("Agent", agent_id)
    best_estimator = gridSearch(model, param_grid, input_train_data, label_train_data)
    input_test_data = test_data[agent_id][:, :5]
    label_test_data = test_data[agent_id][:, 7]
    print("Test R2 score:", best_estimator.score(input_test_data, label_test_data))

    train_preds = best_estimator.predict(input_train_data)
    test_preds =best_estimator.predict(input_test_data)
    print("Train MSE: ", mean_squared_error(label_train_data, train_preds))
    print("Test MSE: ", mean_squared_error(label_test_data, test_preds))

# cv fault is 5
# Out:
# Agent 0
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# CV score for GS 0.7201264645863541
# Test R2 score: 0.7508604636405432
# Train MSE:  0.001424927784987889
# Test MSE:  0.0060052437029640094
# Agent 1
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# CV score for GS 0.6584151692683586
# Test R2 score: 0.7258726654908589
# Train MSE:  0.0030897250841774187
# Test MSE:  0.0071406869607265255
# Agent 2
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# CV score for GS 0.8096263989429013
# Test R2 score: 0.8537063407893775
# Train MSE:  0.005629704438448359
# Test MSE:  0.009826289094897748
# Agent 3
# Param for GS {'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# CV score for GS 0.7665308881963314
# Test R2 score: 0.7446631906188128
# Train MSE:  0.00344158536077645
# Test MSE:  0.012859172156017144
# Agent 4
# Param for GS {'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 5}
# CV score for GS 0.7729158078305184
# Test R2 score: 0.6644946293806726
# Train MSE:  0.00458231094041248
# Test MSE:  0.018678409951648194
# Agent 5
# Param for GS {'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 15}
# CV score for GS 0.8361228414936146
# Test R2 score: 0.8625603306913752
# Train MSE:  0.002052330241792352
# Test MSE:  0.0037512081097618778
# Agent 6
# Param for GS {'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 2}
# CV score for GS 0.7311227275090552
# Test R2 score: 0.7779753908662939
# Train MSE:  0.004234178813274101
# Test MSE:  0.011187901936153741
# Agent 7
# Param for GS {'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# CV score for GS 0.80938296644985
# Test R2 score: 0.7856799147992346
# Train MSE:  0.004894736426847676
# Test MSE:  0.014373114309771543
# Agent 8
# Param for GS {'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 2}
# CV score for GS 0.6414743426921923
# Test R2 score: 0.6184329479941244
# Train MSE:  0.006312857407948839
# Test MSE:  0.02209334056281329
# Agent 9
# Param for GS {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.7374732559028208
# Test R2 score: 0.6856782202918946
# Train MSE:  0.007118408085457364
# Test MSE:  0.016266504967999754
# Agent 10
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# CV score for GS 0.7590448127036614
# Test R2 score: 0.7510551905179832
# Train MSE:  0.00314157427112988
# Test MSE:  0.00831570586672772
# Agent 11
# Param for GS {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.6913663165896647
# Test R2 score: 0.7136289526778671
# Train MSE:  0.007546481060020078
# Test MSE:  0.01502996019532837
# Agent 12
# Param for GS {'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 10}
# CV score for GS 0.7218340740695703
# Test R2 score: 0.7746500176144921
# Train MSE:  0.007718894921900339
# Test MSE:  0.021822246526652895
# Agent 13
# Param for GS {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.2164243316378168
# Test R2 score: 0.4446085423135375
# Train MSE:  0.000560342581993319
# Test MSE:  0.0004526868410660508
# Agent 14
# Param for GS {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.6409483499023889
# Test R2 score: 0.563553453431497
# Train MSE:  0.0015445673943020263
# Test MSE:  0.0029069467234544492

# %%
# context with gamma
for agent_id in trained_data.keys():
    input_train_data = trained_data[agent_id][:, :5]
    label_train_data = trained_data[agent_id][:, 8]
    print("Agent", agent_id)
    best_estimator = gridSearch(model, param_grid, input_train_data, label_train_data)
    input_test_data = test_data[agent_id][:, :5]
    label_test_data = test_data[agent_id][:, 8]
    print("Test R2 score:", best_estimator.score(input_test_data, label_test_data))

    train_preds = best_estimator.predict(input_train_data)
    test_preds =best_estimator.predict(input_test_data)
    print("Train MSE: ", mean_squared_error(label_train_data, train_preds))
    print("Test MSE: ", mean_squared_error(label_test_data, test_preds))
# Out:
# Agent 0
# Param for GS {'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.10931191270133933
# Test R2 score: 0.18498440495961244
# Train MSE:  0.00024084850037273936
# Test MSE:  0.00027705017893285566
# Agent 1
# Param for GS {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# CV score for GS 0.33053575325059953
# Test R2 score: 0.2907703094884655
# Train MSE:  0.001859758009916586
# Test MSE:  0.0022085945662352136
# Agent 2
# Param for GS {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 1.0
# Test R2 score: 1.0
# Train MSE:  0.0
# Test MSE:  0.0
# Agent 3
# Param for GS {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.6479159624934215
# Test R2 score: 0.6320353296426195
# Train MSE:  0.0010430861636455749
# Test MSE:  0.0017394180491209737
# Agent 4
# Param for GS {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 20}
# CV score for GS 0.33912700095153286
# Test R2 score: 0.4193234624710217
# Train MSE:  8.902269658117901e-05
# Test MSE:  0.00011487175941780286
# Agent 5
# Param for GS {'max_depth': 15, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.6271041396456412
# Test R2 score: 0.6051308154890828
# Train MSE:  0.00013219581477389578
# Test MSE:  0.00019797319154973305
# Agent 6
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# CV score for GS 0.7677860665184243
# Test R2 score: 0.776089990344468
# Train MSE:  0.000931889726814168
# Test MSE:  0.002523763018243671
# Agent 7
# Param for GS {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.7036097210930307
# Test R2 score: 0.6289070246624697
# Train MSE:  0.0006891068130950133
# Test MSE:  0.0014468511595938126
# Agent 8
# Param for GS {'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 5}
# CV score for GS 0.6173303488659719
# Test R2 score: 0.6193112497535334
# Train MSE:  0.0007730820190890794
# Test MSE:  0.00305524251692445
# Agent 9
# Param for GS {'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 5}
# CV score for GS 0.7331640411566539
# Test R2 score: 0.7686656053069076
# Train MSE:  0.00029312055034476153
# Test MSE:  0.0008236500199797288
# Agent 10
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# CV score for GS 0.6241503530755385
# Test R2 score: 0.4694335929314368
# Train MSE:  0.00024255214459304066
# Test MSE:  0.0007275227095940879
# Agent 11
# Param for GS {'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.6813751558677288
# Test R2 score: 0.6971211421971942
# Train MSE:  0.0011756964095210177
# Test MSE:  0.0023496440212899365
# Agent 12
# Param for GS {'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# CV score for GS 0.8205776998769639
# Test R2 score: 0.8512611443447395
# Train MSE:  0.0002570179529173748
# Test MSE:  0.0035749775055699544
# Agent 13
# Param for GS {'max_depth': 3, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS -0.012487394193772428
# Test R2 score: -0.004324018828426146
# Train MSE:  0.15669107098017235
# Test MSE:  0.15805594901093492
# Agent 14
# Param for GS {'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.25201681670722975
# Test R2 score: 0.18361851114045136
# Train MSE:  0.0008476604851698792
# Test MSE:  0.0009225185237349777

# %%
# estimated_CTR and value with bid
for agent_id in trained_data.keys():
    input_train_data = trained_data[agent_id][:, 5:7]
    label_train_data = trained_data[agent_id][:, 7]
    print("Agent", agent_id)
    best_estimator = gridSearch(model, param_grid, input_train_data, label_train_data)
    input_test_data = test_data[agent_id][:, 5:7]
    label_test_data = test_data[agent_id][:, 7]
    print("Test R2 score:", best_estimator.score(input_test_data, label_test_data))

    train_preds = best_estimator.predict(input_train_data)
    test_preds =best_estimator.predict(input_test_data)
    print("Train MSE: ", mean_squared_error(label_train_data, train_preds))
    print("Test MSE: ", mean_squared_error(label_test_data, test_preds))
# Out:
# Agent 0
# Param for GS {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# CV score for GS 0.9988509718564229
# Test R2 score: 0.999087904342793
# Train MSE:  9.753688427456076e-06
# Test MSE:  2.198509631181323e-05
# Agent 1
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# CV score for GS 0.9990265575233621
# Test R2 score: 0.9989419553765981
# Train MSE:  5.55840520764875e-06
# Test MSE:  2.756078834575608e-05
# Agent 2
# Param for GS {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.9997593115893435
# Test R2 score: 0.9999506790883373
# Train MSE:  7.532009019459726e-20
# Test MSE:  3.3127993313984634e-06
# Agent 3
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.9988607115157719
# Test R2 score: 0.9985895883030934
# Train MSE:  9.169156121918624e-06
# Test MSE:  7.103060019171279e-05
# Agent 4
# Param for GS {'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.998320621247706
# Test R2 score: 0.9996403709479459
# Train MSE:  4.754101907798671e-08
# Test MSE:  2.0021434686395786e-05
# Agent 5
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# CV score for GS 0.9932541489076119
# Test R2 score: 0.9951474640256532
# Train MSE:  7.144062731094437e-05
# Test MSE:  0.00013244263749649958
# Agent 6
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.9982398445675326
# Test R2 score: 0.9990122866034552
# Train MSE:  8.493112298462223e-06
# Test MSE:  4.977124231717109e-05
# Agent 7
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# CV score for GS 0.9985615083845062
# Test R2 score: 0.9988281404348989
# Train MSE:  3.339616033109388e-05
# Test MSE:  7.858932805303319e-05
# Agent 8
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# CV score for GS 0.9991980083248704
# Test R2 score: 0.9989272865774392
# Train MSE:  1.2001204903411425e-05
# Test MSE:  6.211181716646294e-05
# Agent 9
# Param for GS {'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# CV score for GS 0.9989015892926659
# Test R2 score: 0.9989689255621648
# Train MSE:  1.0453554356232434e-05
# Test MSE:  5.3359259676498574e-05
# Agent 10
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# CV score for GS 0.99879953728058
# Test R2 score: 0.9989207477124787
# Train MSE:  1.1887205773183415e-05
# Test MSE:  3.6051141607224086e-05
# Agent 11
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.9987829310757975
# Test R2 score: 0.9986376303138509
# Train MSE:  1.0854892412337368e-05
# Test MSE:  7.150290626659964e-05
# Agent 12
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.9988333012436496
# Test R2 score: 0.998658164530611
# Train MSE:  2.113224069364062e-05
# Test MSE:  0.00012993950166422405
# Agent 13
# Param for GS {'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.5004500426748393
# Test R2 score: 0.7374715637564957
# Train MSE:  0.0003538636507261756
# Test MSE:  0.00021398090814744427
# Agent 14
# Param for GS {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.998418802540636
# Test R2 score: 0.9970207875590168
# Train MSE:  6.979147596013149e-09
# Test MSE:  1.9843006920050205e-05

# %%
# estimated_CTR and value with gamma
for agent_id in trained_data.keys():
    input_train_data = trained_data[agent_id][:, 5:7]
    label_train_data = trained_data[agent_id][:, 8]
    print("Agent", agent_id)
    best_estimator = gridSearch(model, param_grid, input_train_data, label_train_data)
    input_test_data = test_data[agent_id][:, 5:7]
    label_test_data = test_data[agent_id][:, 8]
    print("Test R2 score:", best_estimator.score(input_test_data, label_test_data))

    train_preds = best_estimator.predict(input_train_data)
    test_preds =best_estimator.predict(input_test_data)
    print("Train MSE: ", mean_squared_error(label_train_data, train_preds))
    print("Test MSE: ", mean_squared_error(label_test_data, test_preds))
# Out:
# Agent 0
# Param for GS {'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.5333169841838611
# Test R2 score: 0.5105262410898854
# Train MSE:  0.00013613352754425153
# Test MSE:  0.0001663879725912051
# Agent 1
# Param for GS {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.962009085796303
# Test R2 score: 0.9586889431602974
# Train MSE:  8.976011500819029e-05
# Test MSE:  0.00012864573618709405
# Agent 2
# Param for GS {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 1.0
# Test R2 score: 1.0
# Train MSE:  0.0
# Test MSE:  0.0
# Agent 3
# Param for GS {'max_depth': 15, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.9718875101456502
# Test R2 score: 0.9740680452867054
# Train MSE:  9.745089426642302e-05
# Test MSE:  0.00012258380684613876
# Agent 4
# Param for GS {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.6373886469247644
# Test R2 score: 0.673742818431487
# Train MSE:  6.607779996546023e-05
# Test MSE:  6.454150296643999e-05
# Agent 5
# Param for GS {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CV score for GS 0.7798038048079551
# Test R2 score: 0.7722242670939672
# Train MSE:  0.00010195052560827014
# Test MSE:  0.00011419855124131654
# Agent 6
# Param for GS {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 15}
# CV score for GS 0.991633987199527
# Test R2 score: 0.9919873540769215
# Train MSE:  4.281777650295583e-05
# Test MSE:  9.03131552272106e-05
# Agent 7
# Param for GS {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.9720861079867804
# Test R2 score: 0.9708684656795307
# Train MSE:  8.569096800372656e-05
# Test MSE:  0.00011358068466260006
# Agent 8
# Param for GS {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 20}
# CV score for GS 0.9864973168522149
# Test R2 score: 0.9863357463027858
# Train MSE:  5.4102052964510156e-05
# Test MSE:  0.00010966336365532882
# Agent 9
# Param for GS {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.9593778392129438
# Test R2 score: 0.9673642205345436
# Train MSE:  9.045225948552258e-05
# Test MSE:  0.00011619742254254516
# Agent 10
# Param for GS {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.9248232442183785
# Test R2 score: 0.9381601671768273
# Train MSE:  9.084049690938371e-05
# Test MSE:  8.479595039748939e-05
# Agent 11
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# CV score for GS 0.9817804755400698
# Test R2 score: 0.9856591731396769
# Train MSE:  8.200736567637724e-05
# Test MSE:  0.00011125186596764851
# Agent 12
# Param for GS {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 15}
# CV score for GS 0.9970739545722338
# Test R2 score: 0.9971666747588418
# Train MSE:  3.273298401609514e-05
# Test MSE:  6.80997171753211e-05
# Agent 13
# Param for GS {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 15}
# CV score for GS -0.004278631068474037
# Test R2 score: -0.011018169644738451
# Train MSE:  0.15684493570653957
# Test MSE:  0.15910944403869376
# Agent 14
# Param for GS {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# CV score for GS 0.8958783900932783
# Test R2 score: 0.8833907491103534
# Train MSE:  0.00010112125421810621
# Test MSE:  0.00013176951639953902

# %%
agent_id = 3
input_train_data = trained_data[agent_id][:, 5:7]
label_train_data = trained_data[agent_id][:, 8]
print("Agent", agent_id)
best_estimator = gridSearch(model, param_grid, input_train_data, label_train_data)
input_test_data = test_data[agent_id][:, 5:7]
label_test_data = test_data[agent_id][:, 8]
print("Test R2 score:", best_estimator.score(input_test_data, label_test_data))

train_preds = best_estimator.predict(input_train_data)
test_preds =best_estimator.predict(input_test_data)
print("Train MSE: ", mean_squared_error(label_train_data, train_preds))
print("Test MSE: ", mean_squared_error(label_test_data, test_preds))
# Out:
# Agent 3
# Param for GS {'max_depth': 15, 'min_samples_leaf': 15, 'min_samples_split': 2}
# CV score for GS 0.9718875101456502
# Test R2 score: 0.9740680452867054
# Train MSE:  9.745089426642302e-05
# Test MSE:  0.00012258380684613876

# %%
label_train_data
# Out:
# array([0.6571148 , 0.84637403, 0.73560059, ..., 0.84218544, 0.74103725,
#        0.82448155])

# %%
label_train_data
# Out:
# array([1.        , 1.        , 0.29414657, ..., 0.        , 0.        ,
#        1.        ])

# %%
train_preds
# Out:
# array([0.56458396, 0.63327402, 0.56458396, ..., 0.56458396, 0.57492661,
#        0.63327402])

# %%
# plot the tree
plt.figure(figsize=(15,10))  # Set the figure size (optional)
tree.plot_tree(best_estimator, filled=True, max_depth=3)
plt.show()
